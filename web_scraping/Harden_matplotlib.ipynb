# %% [markdown]
# # Harden Matplotlib
#
# * Continue using our harden_james.csv to plot stats with matplotlib

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir("./game_logs/")

# %%
df= pd.read_csv('2018_19_Harden_James.csv')

# %%
df.columns
# Out:
# Index(['game_season', 'date_game', 'age', 'team_id', 'opp_id', 'game_result',
#        'gs', 'mp', 'fg', 'fga', 'fg_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft',
#        'fta', 'ft_pct', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'game_score', 'plus_minus', 'g', 'home_game', 'win',
#        'pts_per_36', 'trb_per_36', 'tov_per_12'],
#       dtype='object')

# %% [markdown]
# ### Simple Line Chart with Fake Data

# %%
x= [1, 2, 3]
y = [3, 9, 4]
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Plot Harden Points vs. Game Number

# %%
x = df[df.g==1]['game_season']
y = df[df.g==1]['pts']
plt.plot(x,y)
plt.show()

# %%
# Adding labels and a title
x = df[df.g==1]['game_season']
y = df[df.g==1]['pts']

plt.plot(x,y)
plt.xlabel("Played Game Number")
plt.ylabel('Points Scored')
plt.title("2018-19 James Harden Points vs. Game Number")
plt.show()

# %% [markdown]
# ### Bar Chart of Points v Game Number

# %%
plt.figure(figsize=(15,7))
# Adding labels and a title
x = df[df.g==1]['game_season']
y = df[df.g==1]['pts']
shots = df[df.g==1]['fga']

plt.plot(x, y, color = 'k', linewidth= 3, label = 'pts')
plt.bar(x,shots, color = 'r', label = 'fga')

plt.xlabel("Played Game Number")
plt.ylabel('Points Scored')
plt.title("2018-19 James Harden Points vs. Game Number")
plt.legend()
plt.show()

# %%
bins = [i for i in range(0, 80, 5)]
plt.hist(y, bins = bins, rwidth=.95, color = 'r')
plt.xlabel('Point Bins')
plt.ylabel('Frequency')
plt.title('Histogram of James Harden Pts Scored per Game')
# Out:
# Text(0.5, 1.0, 'Histogram of James Harden Pts Scored per Game')

# %%
range(0,80,10)
# Out:
# range(0, 80, 10)
